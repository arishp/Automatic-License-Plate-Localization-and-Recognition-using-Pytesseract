# %% [markdown]
# <a href="https://colab.research.google.com/github/arishp/Automatic-License-Plate-Localization-and-Recognition-using-Pytesseract/blob/master/yolo_darknet_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls drive/MyDrive/colab_ds/
# Out:
# 85561676e53d11eb.zip		happy-or-sad.zip     twitter.zip
# dogs-vs-cats.zip		kaggle.json	     VeRi.zip
# facial-keypoints-detection.zip	twitter_classes.npy

# %%
# !nvidia-smi
# Out:
# Fri Jul 23 05:52:01 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !ls /usr/local/cuda/bin/
# Out:
# bin2c			      fatbinary			   nvdisasm
# computeprof		      ncu			   nvlink
# compute-sanitizer	      ncu-ui			   nv-nsight-cu
# crt			      nsight_ee_plugins_manage.sh  nv-nsight-cu-cli
# cudafe++		      nsight-sys		   nvprof
# cuda-gdb		      nsys			   nvprune
# cuda-gdbserver		      nsys-exporter		   nvvp
# cuda-install-samples-11.0.sh  nsys-ui			   ptxas
# cuda-memcheck		      nvcc
# cuobjdump		      nvcc.profile

# %%
import os
# !rm -fr darknet
# !git clone https://github.com/AlexeyAB/darknet/
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15283, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 15283 (delta 40), reused 50 (delta 26), pack-reused 15186
# Receiving objects: 100% (15283/15283), 13.78 MiB | 16.41 MiB/s, done.
# Resolving deltas: 100% (10351/10351), done.

# %%
# !apt install gcc-5 g++-5 -y
# !ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc 
# !ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++

# %%
# !ls
# Out:
# darknet  drive	sample_data

# %%
# %cd darknet
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !make

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# !chmod a+x ./darknet
# Out:
# --2021-07-23 06:05:10--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  72.6MB/s    in 3.5s
#
# 2021-07-23 06:05:13 (68.1 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# !pwd
# Out:
# /content/darknet

# %%
# !apt install ffmpeg libopencv-dev libgtk-3-dev python-numpy python3-numpy libdc1394-22 libdc1394-22-dev libjpeg-dev libtiff5-dev libavcodec-dev libavformat-dev libswscale-dev libxine2-dev libgstreamer1.0-dev libgstreamer-plugins-base1.0-dev libv4l-dev libtbb-dev qtbase5-dev libfaac-dev libmp3lame-dev libopencore-amrnb-dev libopencore-amrwb-dev libtheora-dev libvorbis-dev libxvidcore-dev x264 v4l-utils unzip

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-712c11b3-4c58-4657-baf7-52026144c675" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-712c11b3-4c58-4657-baf7-52026144c675">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.mp4 to test.mp4

# %%
# !./darknet detector demo cfg/coco.data cfg/yolov3.cfg yolov3.weights -dont_show test.mp4 -i 0 -out_filename output1.avi -thresh 0.7
# Out:
# Streaming output truncated to the last 5000 lines.
# FPS:35.4 	 AVG_FPS:37.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.6 	 AVG_FPS:37.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.4 	 AVG_FPS:37.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.5 	 AVG_FPS:37.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.6 	 AVG_FPS:37.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.6 	 AVG_FPS:37.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.4 	 AVG_FPS:37.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.5 	 AVG_FPS:37.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.5 	 AVG_FPS:37.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.7 	 AVG_FPS:37.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.2 	 AVG_FPS:37.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.4 	 AVG_FPS:37.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.2 	 AVG_FPS:37.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.3 	 AVG_FPS:37.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.5 	 AVG_FPS:37.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:35.6 	 AVG_FPS:37.5
#
#  cvWriteFrame
# Objects:
#
#
# ...

# %%
from google.colab import files
files.download('output1.avi')
